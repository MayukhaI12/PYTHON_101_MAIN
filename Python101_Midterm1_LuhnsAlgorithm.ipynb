# %% [markdown]
# <a href="https://colab.research.google.com/github/MayukhaI12/Mid-term-project/blob/main/Mid_term_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mid-term project: Luhn's Algorithm
#
# ###Validating credit card numbers
# ---
# Date: 12/17/2022
#
# By: Mayukha Ivaturi

# %%
# Defining the 'is_credit' function

# This function is used to validate a credit card number using Luhn's Algorithm.

# The function is coded to return 'True' or 'False'. 
# If it returns 'True' the credit card number is valid; If it returns 'False' the credit card number is invalid.

def is_credit(str):
## Checking to see if the credit card number entered contains any letters. If it doesn't, we run the rest of the code. 
## If it does contain any letters, the function automatically returns 'False' and informs the user. (Line 36-37)
  if(str.isnumeric() == True):
### Converting the credit card number to a list so that we can check through every individual element.
    Credit_No = list(str)
#### Using Luhn's algorithm to make sure the number entered meets all the requirements to be a valid credit card number.
    Check_No = Credit_No
    Sum = 0 
    i = len(Credit_No) -1
    j=0
    for j in range (0, len(Credit_No)):
        
        if (j%2 == 0):
          Check_No[i] = int(Credit_No[i])
        else:
          if (int(Credit_No[i])*2 >= 10):
            Check_No[i] = int(((int(Credit_No[i])*2)/10)) + ((int(Credit_No[i])*2)%10)
          else:
            Check_No[i] = int(Credit_No[i])*2
        Sum = Sum + Check_No[i] 
        i = i -1
        if (i == -1):
          break
    if(Sum%10 == 0):
##### If the number meets all the requirements, it is a possible credit card number and passes Luhn's algorithm. the function returns 'True'.
      return True
    else:
###### If the number does not meet all the requirements, the function returns 'False'.
      return False
  else:
    print("All characters in the card number must be numeric. Please try again.")
    return False

#############################################
    
#Defining the 'is_Visa' function

# This function is coded to tell us if the credit card number given is a valid Visa card number or not.

# The function is coded to return 'True' or 'False'. 
# It calls the 'is_credit' function if the credit card number is a valid Visa card number.
# If it returns 'False' the credit card number is an invalid Visa card number.

def is_Visa(str):
## Converting the credit card number to a list so that we can check through every individual element.
  Credit_Num = list(str)
### Checking if the number meets all the requirements to be a valid Mastercard number.
  if ((len(Credit_Num) == 13 or len(Credit_Num) == 16) and (Credit_Num[0] == "4")):
#### Converting the credit card number back to a string.
    str=""
    for ele in Credit_Num:
      str += ele
##### Calling the 'is_credit' function to ensure that the number given is a valid credit card number. 
    return is_credit(str)
  else: 
###### If the credit card number does not meet the requirements, it is not a Visa number. The function returns 'False'.
    return False

#############################################
    
#Defining the 'is_MasterCard' function

# This function is coded to tell us if the credit card number given is a valid Mastercard number or not.

# The function is coded to return 'True' or 'False'. 
# It calls the 'is_credit' function if it is a valid Mastercard number. 
# If it returns 'False' the credit card number is an invalid Mastercard number.

def is_MasterCard(str):
## Converting the credit card number to a list so that we can check through every individual element.
  CreditNum = list(str)
### Checking if the number meets all the requirements to be a valid Mastercard number.
  if ((len(CreditNum) == 16) and (CreditNum[0] == "5") and (CreditNum[1] == "1" or CreditNum[1] == "2" or CreditNum[1] == "3" or CreditNum[1] == "4" or CreditNum[1] == "5")):
#### Converting the credit card number back to a string.
    str=""
    for ele in CreditNum:
      str += ele
##### Calling the 'is_credit' function to ensure that the number given is a valid credit card number. 
    return is_credit(str)
  else:
###### If the credit card number does not meet the requirements, it is not a Mastercard number. The function returns 'False'.
    return False

#############################################
    
#Defining the main function

## This function is made up of test cases to test the functions coded above.

def main():
  print('\n==>1. Basic test cases (positive)')

  print("is_credit('6011000000000004')", is_credit("6011000000000004"))
  print("is_credit('79927398713')", is_credit("79927398713"))
  print("is_credit('30000000000004')" ,is_credit("30000000000004"))
  print("is_credit('6911600873502604')"  ,is_credit("6911600873502604"))
  print("is_credit('1234567890')",  is_credit("1234567890"))

  print('\n==>2. Negative Test Case')

  print("is_credit('abcdefg')", is_credit("abcdefg"))

  print('\n==>3. Checking whether a card is valid visa card or not')

  print("is_Visa('6011000000000004')",is_Visa("6011000000000004"))
  print("is_Visa('79927398713')", is_Visa("79927398713"))
  print("is_Visa('4012888888881881')" ,is_Visa("4012888888881881"))
  print("is_Visa('4111111111111111')",  is_Visa("4111111111111111"))

  print('\n==>4. Checking whether a card is valid Master card or not')

  print("is_MasterCard('5555555555554444')",is_MasterCard("5555555555554444"))
  print("is_MasterCard('79927398713')", is_MasterCard("79927398713"))
  print("is_MasterCard('5105105105105100')" ,is_MasterCard("5105105105105100"))
  print("is_MasterCard('6911600873502604')"  ,is_MasterCard("6911600873502604"))

#############################################

# Calling the main function

main()
# Out:
# ==>1. Basic test cases (positive)
# is_credit('6011000000000004') True
# is_credit('79927398713') True
# is_credit('30000000000004') True
# is_credit('6911600873502604') False
# is_credit('1234567890') False
#
# ==>2. Negative Test Case
# All characters in the card number must be numeric. Please try again.
# is_credit('abcdefg') False
#
# ==>3. Checking whether a card is valid visa card or not
# is_visa('6011000000000004') False
# is_visa('79927398713') False
# is_visa('4012888888881881') True
# is_visa('4111111111111111') True
#
# ==>4. Checking whether a card is valid Master card or not
# is_mastercard('5555555555554444') True
# is_mastercard('79927398713') False
# is_mastercard('5105105105105100') True
# is_mastercard('6911600873502604') False

# %% [markdown]
# # Output For The Above Program
#
#
# ###==>1. Basic test cases (positive)
#
# - is_credit('6011000000000004') True
#
# - is_credit('79927398713') True
#
# - is_credit('30000000000004') True
#
# - is_credit('6911600873502604') False
#
# - is_credit('1234567890') False
#
#
# ###==>2. Negative Test Case
#
# - is_credit('abcdefg')
#
# - The card number must be numeric. Please try again.
#
# ###==>3. Checking whether a card is valid visa card or not
#
# - is_visa('6011000000000004') False
#
# - is_visa('79927398713') False
#
# - is_visa('4012888888881881') True
#
# - is_visa('4111111111111111') True
#
# ###==>4. Checking whether a card is valid Master card or not
#
# - is_mastercard('5555555555554444') True
#
# - is_mastercard('79927398713') False
#
# - is_mastercard('5105105105105100') True
#
#
# -----------
# ----------
# ----------

# %% [markdown]
# #List Of Variables
#
# ###is_credit
#
# - str = the variable which is used to run the function.
# - Credit_No = the variable used to register the credit card number after it is converted to a list.
# - Check_No = the variable used to register the credit card number after its digits are reversed.
#   - In Luhn's algorithm, we start to double every second digit from the right column. So I coded the program to reverse the digits, then double the digits.
# - Sum = the variable which registers the sum of the digits in the credit card number after doing everything else Luhn's algorithm requires.
#
# -------------------------------------------------------------------------------------------------------------------
# ###is_Visa
#
# - str = the variable which is used to run the function.
# - Credit_Num = the variable used to register the credit card number after it is converted to a list.
#
# -------------------------------------------------------------------------------------------------------------------
# ###is_MasterCard
#
# - str = the variable which is used to run the function.
# - Credit_No = the variable used to register the credit card number after it is converted to a list.
